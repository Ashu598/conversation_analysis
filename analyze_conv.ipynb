# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashu598/conversation_analysis/blob/main/analyze_conv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/conversation_data.csv")
df
# Out:
#                               conversation_id  \
# 0      t_d004c097-424d-45d4-8f91-833d85c2da31
# 1      t_d004c097-424d-45d4-8f91-833d85c2da31
# 2      t_d004c097-424d-45d4-8f91-833d85c2da31
# 3      t_d004c097-424d-45d4-8f91-833d85c2da31
# 4      t_d004c097-424d-45d4-8f91-833d85c2da31
# ...                                       ...
# 11755  t_17c6e54c-24c1-4f48-bcd4-a18278380268
# 11756  t_17c6e54c-24c1-4f48-bcd4-a18278380268
# 11757  t_17c6e54c-24c1-4f48-bcd4-a18278380268
# 11758  t_17c6e54c-24c1-4f48-bcd4-a18278380268
# 11759  t_17c6e54c-24c1-4f48-bcd4-a18278380268
#
#                                              article_url config  \
# 0      https://www.washingtonpost.com/sports/colleges...      C
# 1      https://www.washingtonpost.com/sports/colleges...      C
# 2      https://www.washingtonpost.com/sports/colleges...      C
# 3      https://www.washingtonpost.com/sports/colleges...      C
# 4      https://www.washingtonpost.com/sports/colleges...      C
# ...

# %%
-def summarize_chat(conversation_id):
    chat_df = df[df["conversation_id"] == conversation_id]

    # Extract article link
    article_url = chat_df["article_url"].iloc[0]

    # Count messages per agent
    agent_counts = chat_df["agent"].value_counts().to_dict()

    # Overall sentiment per agent
    sentiment_summary = chat_df.groupby("agent")["sentiment"].apply(lambda x: x.mode()[0]).to_dict()

    # Required Cols of dataframe
    final_df = chat_df[chat_df['agent']=='agent_1'][['message', 'sentiment', 'turn_rating', 'agent_1_rating', 'agent_2_rating']]

    # Return summary
    return final_df, {
        "article_url": article_url,
        "messages_by_agents": agent_counts,
        "overall_sentiment_by_agent": sentiment_summary
    }

# Example Usage
conversation_id = "t_a13a48fd-c053-4055-8448-b61f61c41642"
chat_summary = summarize_chat(conversation_id)
print(chat_summary)
# Out:
# (                                                 message  \
# 10873                        Hey! Do you watch football?
# 10875  Yes, me too. I didn't know that the highest sc...
# 10877    It could be. Georgia Tech defeated Cumberland.
# 10879  It's true. He is awesome. I guess quaterback i...
# 10881  Yes, only at Austin, when I was a student at U...
# 10883  Not sure, but I guess it's sort of influence o...
# 10885  I'm sure there is special government agency or...
# 10887  Did you know that there is a website, which co...
# 10889  Not sure. I guess it's like theater performanc...
# 10891  Really? I didn't know. Yes, radio was popular ...
# 10893  True. Ok. It was nice to meet you and chat her...
#
#                     sentiment turn_rating agent_1_rating agent_2_rating
# 10873                 Neutral        Good           Good      Excellent
# 10875               Surprised        Good           Good      Excellent
# ...
